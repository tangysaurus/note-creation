# %%
from pydantic import BaseModel, Field
from openai import OpenAI
from dotenv import load_dotenv
from typing import List

# %%
load_dotenv()
client = OpenAI()

# %%
class SentenceLine(BaseModel):
    """Schema for a transcript line"""
    line_number: int = Field(..., description="Line number in the transcript")
    text: str = Field(..., description="The sentence on this line")

class Section(BaseModel):
    """Schema for a transcript section"""
    header: str = Field(..., description="Header/title of the section")
    summary: str = Field(..., description = "Brief summary of the section")
    start_line: int = Field(..., description="Start line number of the section (inclusive)")
    end_line: int = Field(..., description="End line number of the section (inclusive)")

class AnnotatedTranscript(BaseModel):
    """Schema for a transcript"""
    summary: str = Field(..., description = "Detailed summary of the transcript")
    sections: List[Section] = Field(..., description="List of structured transcript sections")

# %%
def is_transcript_valid(split_transcript: dict, transcript_sections: list[dict]) -> tuple[bool, str]:
    """Check if annotated transcript is valid"""
    # length checking
    if transcript_sections[-1]["end_line"] > len(split_transcript):
        return False, "Annotated transcript contains more lines than original transcript"
    
    for i in range(len(transcript_sections)):
        transcript_section = transcript_sections[i]
        # type checking
        if (not isinstance(transcript_section["header"], str) or 
            not isinstance(transcript_section["summary"], str) or 
            not isinstance(transcript_section["start_line"], int) or 
            not isinstance(transcript_section["end_line"], int)):
            return False, "Section variables types are wrong"
        # value checking
        if (not transcript_section["header"] or 
            not transcript_section["summary"] or 
            not transcript_section["start_line"] >= 0 or 
            not transcript_section["end_line"] >= 0):
            return False, "Missing section information"
        
        if transcript_sections[i]["end_line"] < transcript_sections[i]["start_line"]:
            return False, "End line comes before start line"
        
        if i >= 1 and transcript_sections[i]["start_line"] != transcript_sections[i-1]["end_line"] + 1:
            return False, "Sections overlap, current section's start line comes before previous section's end line"
        
    return True, ""

# %%
def annotate_transcript(split_transcript: dict, messages: list[dict], iteration: int = 0) -> list[dict]:
    """Create an annotated transcript, broken up into sections by line numbers"""
    if iteration > 4:
        return
    
    res = client.beta.chat.completions.parse(
        model = "gpt-4.1",
        messages = messages,
        response_format = AnnotatedTranscript
    )

    annotated_transcript = res.choices[0].message.parsed.model_dump()
    messages.append({"role": "user", "content": str(annotated_transcript)})
    transcript_sections = annotated_transcript["sections"]

    is_valid = is_transcript_valid(split_transcript, transcript_sections)

    if not is_valid[0]:
        messages.append({"role": "user", "content": f"Re-annotate the transcript to address the following error: {is_valid[1]}"})
        annotate_transcript(split_transcript, messages, iteration + 1)
    return transcript_sections

# %%
def split_transcript_into_lines(transcript: str) -> dict:
    """
    Splits a raw transcript string into a list of lines.
    Returns a dictionary, with line number to line mappings
    """
    split_transcript = transcript.split('.')
    line_mappings = {index: line.strip() for index, line in enumerate(split_transcript)}
    return line_mappings

# %%
def normalize_section(section: dict, split_transcript: dict) -> dict:
    """Normalize a transcript section by combining lines into a single string"""
    transcript = ""
    start_line = section["start_line"]
    end_line = section["end_line"]

    for i in range(start_line, end_line):
        transcript += split_transcript[i] + "\n"

    return {
        "header": section["header"], 
        "summary": section["summary"], 
        "transcript": transcript
    }

# %%
class NoteSection(BaseModel):
    """Schema for a note section"""
    header: str = Field(..., description="Short, catchy header/title of the section formatted in markdown using '##'. Include a relevant emoji.")
    one_liner: str = Field(..., description = "Short, interesting, one-liner that encapsulates section. Put the one-liner in "". Use > 'quote' markdown")
    content: str = Field(..., description = "Detailed, bullet-points illustrating the section")

# %%
def generate_note_section(transcript_section: dict, split_transcript: dict) -> dict:
    """Combine transcript section metadata and content to create a note section"""
    normalized_section = normalize_section(transcript_section, split_transcript)
    res = client.beta.chat.completions.parse(
        model = "gpt-4.1",
        messages = [
            {
                "role": "system", 
                "content": 
                    """
                    You are a course creator for a college class. 
                    Use the following section header, summary, and transcript to create a detailed note.
                    Indicate subheaders using '##', bold key terms and concepts for emphasis, use bullet points to represent lists, and indentation to indicate dependencies.
                    Format headers, one-liners, and text in markdown. Format math equations and symbols in katex.
                    """
            },
            {
                "role": "user", 
                "content": f"header: {normalized_section['header']} \n summary: {normalized_section['summary']} \n transcript: {normalized_section['transcript']}"
            }
        ],
        response_format = NoteSection
    )
    note_section = res.choices[0].message.parsed.model_dump()
    return note_section

# %%
def compile_note_section(note_section: dict) -> str:
    """Combine note section components into a string"""
    combined = note_section["header"] + "\n" + note_section["one_liner"] + "\n" + note_section["content"]
    return combined

# %%
class Extras(BaseModel):
    """Schema for additional content"""
    headline: str = Field(..., description = "Short, catchy title that encapsulates this lecture. Formatted in markdown using '##'.")
    summary: str = Field(..., description = "Short, engaging outline of the lecture. Begin with 'This lecture covers...'. Italicize in markdown using '*'.")
    todo_list: str = Field(
                            ..., 
                            description = 
                                    """
                                        Short list of the most important todos and next steps mentioned by the professor in the lecture. 
                                        Prioritize readings, exams, and assignments. 
                                        Include deadlines. 
                                        Format the title 'Todo List' in markdown using '###'.
                                        Use markdown format to **bold** parts of each todo. Keep each todo to 15 words or less. 
                                        Include markdown checkboxes '- [ ]' before each todo.
                                    """
                        )
    glossary: str = Field(..., description = "Glossary of key terms and definitions used throughout the lecture. Format the title 'Glossary' in markdown using '###'. Format the glossary as a markdown table with a divider '---' at the end.")
    quiz: str = Field(..., description = "Written quiz that tests a student's understanding of the lecture. Format the title 'quiz' in markdown using '###'.")
    answers: str = Field(..., description = "Answers to the written quiz. Format the title 'answers' in markdown using '###'.")

# %%
def generate_extras(transcript: str) -> dict:
    """Generate additional content"""
    res = client.beta.chat.completions.parse(
        model = "gpt-4.1",
        messages = [
            {
                "role": "system", 
                "content": 
                    """
                    You are a course creator for a college class. 
                    Generate a headline, summary, todo list, glossary, and quiz that reflects the following transcript.
                    Indicate subheaders using '##', bold key terms and concepts for emphasis, use bullet points to represent lists, and indentation to indicate dependencies.
                    Format the response in markdown. Format math equations and symbols in katex.
                    """
            },
            {
                "role": "user", 
                "content": transcript
            }
        ],
        response_format = Extras
    )
    extras = res.choices[0].message.parsed.model_dump()
    return extras

# %%
def compile_note(transcript: str) -> str:
    """
    Break a transcript into semantically meaningful sections
    Generate a note for each section, and additional content for the transcript
    Combine each note and additional content together
    """
    split_transcript = split_transcript_into_lines(transcript)
    messages = [
        {
            "role": "system", 
            "content": "Break the following transcript into 5 or 6 sections using the provided line numbers."
        },
        {
            "role": "user", 
            "content": str(split_transcript)
        }
    ]
    transcript_sections = annotate_transcript(split_transcript, messages)
    compiled_note_sections = []

    for transcript_section in transcript_sections:
        note_section = generate_note_section(transcript_section, split_transcript)
        compiled_note = compile_note_section(note_section)
        compiled_note_sections.append(compiled_note)

    extras = generate_extras(transcript)

    combined_note_sections = ""
    for compiled_note_section in compiled_note_sections:
        combined_note_sections += compiled_note_section + "\n"

    combined_note = (
                        extras["headline"] + 
                        "\n" +
                        extras["summary"] + 
                        "\n" +
                        extras["todo_list"] + 
                        "\n" +
                        combined_note_sections +
                        extras["glossary"] +
                        "\n" +
                        extras["quiz"] +
                        "\n" +
                        extras["answers"]
                    )
    return combined_note

# %%
with open("C:/Users/Kaden/OneDrive/Professional/Athena/Note Creation/Semantic Chunking/transcripts/positionality.txt", encoding = "utf-8-sig") as f:
    transcript = f.read()

# %%
note = compile_note(transcript)

# %%
print(note)
# Out:
# ## Exploring Positionality, Reality, and Human Behavior in Research and Relationships
# *This lecture covers the foundational concept of **positionality** and its significance in research paradigms, forensic psychology, and critical thinking. Students examine how factors like nature vs. nurture, genetics, and environment shape human behavior—including moral judgments and attraction—and how individual worldviews impact research, relationships, and understanding of reality. Critical realism, skepticism, and differing research paradigms are discussed, with real-world case studies (e.g., policing, military, trauma transmission) illustrating the complexities of positionality in professional and personal analysis. The lecture also addresses the importance of aligning personal positionality with research approaches and includes reflection on practical challenges, boundaries, and self-disclosure in relationships.*
# ### Todo List
# - [ ] **Review readings** on positionality and research paradigms before next class (Due before next session)
# - [ ] **Read case study of Marine A** for upcoming class debate (Due next class)
# - [ ] **Reflect on your own positionality**: Where do you fall on the spectrum? (Due before next seminar)
# - [ ] **Prepare examples of positionality** affecting professional or research decisions (Optional, bring to discussion)
# - [ ] **Note rescheduled lectures**: Monday's and July 29th classes moved; check new times (Action ASAP)
# ## 🌍 Positionality, Paradigms, and the Nature of Knowing
# > 'Your unique position shapes not just what you research, but how you understand reality itself.'
# - **Positionality**
#   - Your unique combination of beliefs, values, life experiences, and identity that influences how you see and interpret the world.
#   - It's critical in research across all disciplines; not knowing your positionality undermines the credibility of your research.
#   - Affects how you validate, generate, and value knowledge—what you consider valid differs from what others may consider valid.
#
# - **Epistemology**
#   - The philosophical theory of knowledge.
#     - Grapples with what constitutes justified belief vs. opinion.
#     - Key question: What knowledge do you see as justified and why?
#
# - **Ontology**
#   - The study of the nature of reality and existence.
#     - Explores whether something fundamentally exists or is possible.
#     - Shapes debates over nature (genetics, biology) vs. nurture (environment, upbringing) in human development.
#
# - **Thought Experiments and Examples**
#   - Nature vs. Nurture debate illustrated with:
#     - Stories of separated twins and inherited traits/interests.
#     - Case studies of criminal behavior in separated-at-birth individuals.
#     - PTSD risk as a function of genetics (nature), environment (nurture), and **epigenetics** (how parental/grandparental experiences affect gene expression in offspring).
#       - Studies (e.g., 9/11 trauma and subsequent generations) show events in one generation can measurably impact psychological risk in descendants.
#       - **Epigenetics**: Even pre-birth stressors can affect gene expression—mechanism isn't fully understood, but the effects are real and observable.
#
# - **Positionality Spectrum & Forensic Psychology**
#   - Worldview differences (belief in innate evil, punishment vs. rehabilitation, procedural vs. retributive justice) affect professional judgments and practices:
#     - Forensic psychologists' beliefs can directly influence decisions on rehabilitation, punishment, and forgiveness.
#     - Researchers' and practitioners' values/epistemologies affect evaluation and action—this is the core of positionality in applied fields.
#
# - **Why It Matters**
#   - How you define 'reality' and 'knowledge' will impact what you choose to study, how you interpret findings, and even day-to-day professional decisions.
#   - Reflecting on your own **positionality** is essential for rigorous, ethical, and impactful research and practice.
# ## 🧬 Nature vs. Nurture, Epigenetics, and Forensic Psychology
# > The debate over nature vs. nurture goes deeper, exploring how genes, environments, and even past traumas can shape who we are.
# - **Nature vs. Nurture Debate**
#     - Central question: Are psychological traits and disorders more influenced by genetics (**nature**) or environment/experience (**nurture**)?
#     - Personal beliefs about this influence clinical perspectives and diagnoses:
#         - Some practitioners lean toward genetic explanations.
#         - Others emphasize environmental or situational causes.
#
# - **Philosophical and Scientific Arguments**
#     - Arguments can rest on metaphysical concepts like infinite regress (e.g., 'turtles all the way down'), questioning at what point an explanation is sufficient.
#     - Foundation of knowledge:
#         - **Foundationalism**: Some base beliefs are self-evident or need no further support.
#         - **Coherentism**: Knowledge builds a consistent network (like imagining a leopard and rain because both are empirically experienced).
#     - Empiricism plays a key role—direct experience validates what we know.
#
# - **Forensic Psychology and Skepticism**
#     - In practice, forensic psychologists can challenge both the *validity of facts (the 'what')* and the *validity of methods (the 'how')*:
#         - "I know what it's like to sit on a chair."→ How do you know? Could it be imagination?
#     - This skepticism is essential in legal and clinical settings for testing the robustness of arguments or diagnoses.
#     - Prosecutorial logic: In court, you don't need to prove your own point, just cast doubt on the other side's explanation.
#
# - **Epigenetics and Trauma Transmission**
#     - New research shows both nature and nurture matter—and even experiences/triggers can modify genes (**epigenetic changes**).
#     - Example: Trauma or PTSD may be passed down ("intergenerational trauma"):
#         - Grandparental or parental experiences can affect later generations at a genetic or behavioral level.
#         - Ongoing research seeks to clarify how these processes work empirically.
#
# - **Conclusion**
#     - Current science sees **genetic predispositions** and **environmental factors** as interacting systems—rarely is it all one or the other.
#     - The debate evolves as empirical evidence for mechanisms like epigenetics grows.
# ## 🧭 Positionality & Research Integrity: Navigating the Landscape of Beliefs
# > Your beliefs shape your research, your practice, and your ethical compass.
# - **Positionality**
#     - Refers to understanding your own beliefs, background, and biases.
#     - Essential for credible research and ethical professional practice.
#     - Self-awareness allows for critical analysis and honest engagement with knowledge.
#
# - **Research Paradigms & Spectrums**
#     - **Objectivism/Naive Realism**: Belief that knowledge must be measurable, falsifiable, and replicated (science-first).
#     - **Structuralism**: What we measure is influenced by social, institutional, and funding structures.
#     - **Critical Realism**: Accepts both objective, measurable reality and the importance of subjective perspectives.
#     - **Relativism**: Reality and truth are always subjective—multiple coexisting realities, all valid in their context.
#     - Individuals often land somewhere along this spectrum, shaping how they interpret data and ideas.
#
# - **Personal Beliefs in Practice**
#     - Choices, attractions, and behaviors often reflect a complex interplay of biology, upbringing, neurology, and personal experiences.
#         - E.g., impact of brain tumors or hormonal shifts on personality and attraction shows biology’s role.
#         - Upbringing and learned experiences (e.g., childhood exposures) can also fundamentally shape preferences and conduct.
#     - Family case studies demonstrate genetic/biological as well as social influences (e.g., children mirroring parents genetically and behaviorally).
#
# - **Implications for Professionals & Students**
#     - Research and practice integrity demand that your chosen methods and topics align with your foundational beliefs and paradigm (coherence).
#         - For example: If you strictly believe in measurable science, choosing to research subjective theories (like critical race theory) may not align with your core beliefs.
#     - Awareness of biases and how they may influence research, diagnoses, or client interactions is crucial.
#
# - **Critical Thinking & Ethical Alignment**
#     - Engage with claims and research from a standpoint of awareness: Can you articulate your alignment? Are you open to validity across spectra?
#     - Research and argument assessment should be based on
#         - Internal coherence (does it make sense internally?)
#         - Foundational adequacy (are the basic assumptions justified?)
#         - Awareness and navigation of skepticism (questioning, but also knowing your own limits of doubt)
#     - Ethical action requires aligning methods, beliefs, and the type of knowledge valued.
#
# - **Key Takeaways**
#     - No single paradigm fits all inquiries; positionality is nuanced and dynamic.
#     - Self-knowledge about where you stand helps you:
#         - Critically assess material
#         - Choose suitable methods
#         - Ensure honest, ethical professional and research conduct.
#     - The process of positioning yourself is ongoing—it must be revisited and re-evaluated as you grow as a scholar and practitioner.
# ## ☕ Break & Banter: Social Decompression and Neurodiversity
# > After deep academia, a candid group unwind with quirky stories, comfort chairs, and honest chats on friendship, flirting, and living with ADHD and dyslexia.
# - **Transition to a relaxed vibe**
#   - Participants move from intense academic discussion to light, personal dialogue.
#   - Conversations about massage chairs and choosing favorite spots for comfort.
#
# - **Social routines and living situations**
#   - Friendly banter about why some people linger at social gatherings or in certain living situations.
#     - Reference to 'long-term orbiters' in social circles who extend stays.
#     - Discussions about boundaries with friendships and visitors.
#
# - **Friend attractions and personality quirks**
#   - Laughter about nerdy, analytical flirting styles – e.g., psychoanalysis instead of classic flirtation.
#   - Jokes about consulting ChatGPT or a GP for dating advice.
#   - Self-reflection on how neurodiversity (dyslexia, ADHD) shapes dating and social experiences.
#     - Playful recognition of overthinking during social or romantic interactions.
#     - Awareness that being "hard to date" can be due to internal dialogue and unique brain wiring.
#
# - **Education, expertise, and humility**
#   - Discussion of graduate studies, and the realization that deep expertise reveals how little is truly known.
#     - "The more specific your knowledge, the more you see how generalized info is often wrong."
#   - Admiration for people who can detach ego from being wrong.
#   - Noting the importance of humility and learning from others in social settings.
#
# - **Neurodiversity: Dyslexia & ADHD experiences**
#   - Personal anecdotes about growing up with dyslexia, spelling challenges, and coping mechanisms.
#     - Adapting approach to wordplay, self-training to manage written/verbal hurdles.
#     - Quick mental filtering—choosing which thoughts or jokes to say aloud.
#     - Recognition that neurodiverse brains add to humor and perspective.
#
# - **Embracing Individuality & Weirdness**
#   - Participants own their quirks and describe mutual understanding among similarly 'weird' friends.
#   - Open discussion of labels, self-analysis, and sharing transparent (sometimes humorous) self-profiles.
#
# - **Core themes:**
#   - **Comfort in community**: Creating a safe, accepting space for all kinds of personalities.
#   - **Honest reflection**: Leaning into vulnerabilities and idiosyncrasies as a form of connection.
#   - **Neurodiversity awareness**: Acknowledging and celebrating different brain types in personal and academic life.
# ## 🌱 Deepening Personal Dialogue: Relationships, Self-Discovery, and Emotional Vulnerability
# > This candid exchange explores the complexity of connection, emotional readiness, and the ethics of love when life is anything but settled.
# - **Honest Self-Assessment**
#   - Both speakers openly share their current instability—personal, financial, geographic, and emotional.
#     - Speaker 3 laments their lack of stability and admits they're not presently fit for partnership, prioritizing their own wellbeing before entering a relationship.
#     - Speaker 8 echoes a desire for stability before building a deeper connection, wanting to feel grounded before inviting someone else in.
#   - Recognition that stability is necessary for healthy, lasting connections, yet both acknowledge the unpredictability of life.
#
# - **Boundaries, Needs, and Relational Ethics**
#   - A desire for **honesty over performative perfection**; both refuse to "pretend" for the sake of appearing like ideal partners.
#   - **Negotiation vs. Compromise:**
#     - Speakers distinguish between negotiation (collaborative) and compromise (someone loses), expressing a preference for negotiation in relationships.
#   - Ethical stance: both want to ensure their involvement benefits everyone ("triple win")—good for me, good for you, good for the relationship/community.
#
# - **Emotional Vulnerability and Mutual Recognition**
#   - Admittance of past wounds and relationship disappointments create caution.
#   - Both value spaces where they don't have to "edit themselves," feeling seen and accepted as they are.
#   - Acknowledgment of deep connection and rare reciprocity despite current life chaos.
#
# - **Desire for Partnership vs. Readiness**
#   - There is a shared wish for a committed, loving relationship—an ideal of monogamy or long-term partnership.
#     - However, both clearly state neither is ready to offer nor demand monogamy or long-term plans given present instability.
#   - Hope exists for a future together, but only if each has resolved enough of their own challenges to meet as equals.
#     - Example: Speaker 3 details needing financial/emotional grounding before being able to "bring someone in."
#
# - **Practical Life Considerations**
#   - Work, relocation, legal issues (e.g., visas, citizenship, teaching jobs, career change), and health—all are variables that weigh on major life and relationship decisions.
#   - Some past (and present) involvement in sex work complicates partnership dynamics and is openly discussed as needing resolution before new relationship commitments.
#
# - **Relational Patterns and Self-Discovery**
#   - Both reflect on how past choices and trauma informed unhealthy patterns (e.g., rescuing partners, or seeking partners in crisis).
#   - Ongoing commitment to self-examination—questioning their motivations and striving to act out of self-awareness, not compulsion or loneliness.
#   - Emphasis on not using others as "placeholders" or to solve their own problems, but valuing genuine companionship.
#
# - **Hope, Play, and Future Imagining**
#   - The dialogue ends on a hopeful, playful note—sharing dreams of future travel, creative work, and "seeing what is possible" if life circumstances align.
#   - Both are clear about maintaining contact and nurturing their bond, yet patient about what shape it may take.
#
# **Key Takeaways:**
# - Relationships in times of change require extra doses of self-awareness, honesty, and patience.
# - Emotional vulnerability is a strength, allowing for deeper mutual recognition—even without guarantees of a future together.
# - Ethics in intimacy matter: ensuring well-being for both self and other, and refusing to build on shaky ground or emotional neediness.
# - It's okay to want and need love—and also okay to wait until you can offer your best self.
# ## 🌱 Closing Reflections: Embracing Uncertainty and Ongoing Journeys
# > Life's transitions bring uncertainty, but also hope, vulnerability, and an openness to new possibilities.
# - **Vulnerable Sharing about the Future:**
#   - Speakers candidly discuss the challenge of building a future, especially when facing personal or logistical barriers (e.g., Speaker 8: "I want to build a life with someone... I can't right now, I'm just trying to create anything out of my life").
#   - Acknowledgement of limited resources other than emotional openness ("I can't even give you anything other than like, you know, emotional intelligence in some ways").
# - **Practical and Emotional Complexities:**
#   - Past negative experiences (e.g., manipulation, financial struggles, relationship trauma) shape current hesitations.
#     - Shared examples: being asked to move in abruptly, being asked to care for someone else's children, fearing violence or emotional instability in relationships.
#   - Importance of honesty over pretense in relationships ("idea that we're supposed to put our best foot forward... makes me angry").
# - **Hope and Desire for Connection:**
#   - Longing for a deep, honest connection persists amid challenges ("I don't want to do you, I want to love you").
#   - A desire to walk through upcoming challenges together, balancing realism with optimism.
# - **Navigating Transitions & Coping Mechanisms:**
#   - Coping with change includes humor, candid reflections, and mutual support.
#     - Light-hearted exchanges about past nights out, mutual friends, and college experiences help ease serious conversations.
# - **Acceptance of Uncertainty:**
#   - Recognition that not everything can be planned or resolved quickly ("not on a six week study run... have your fun").
#   - Acceptance of life’s unpredictability and the necessity of open-ended journeys and questions.
# - **Ending on a Positive, Forward-Looking Note:**
#   - Speakers affirm the value of their friendship and shared interests ("I really love us. We get along really well, and our interests... keep us engaged").
#   - Playful rituals (checking for keys, celebrating with 'Huzzah' stickers) symbolize continuity, care, and optimism for what comes next.
#
# ### Glossary
# | Term                  | Definition |
# |-----------------------|-------------------------------------------------------------------------------------------|
# | **Positionality**     | Your unique position in the world, shaped by personal beliefs, values, knowledge, and perspective. |
# | **Epistemology**      | The philosophical study of knowledge—how we know what we know; concerns justified belief vs. opinion. |
# | **Ontology**          | A branch of philosophy dealing with the nature of reality and being. |
# | **Nature vs. Nurture**| Debate over whether genetics (nature) or environment (nurture) has more influence on behavior. |
# | **Epigenetics**       | Study of how environment can alter gene expression across generations, independent of DNA sequence changes. |
# | **Critical Realism**  | The view that reality exists independently but our understanding is shaped by context and subjectivity. |
# | **Naive Realism**     | Belief that reality is as we perceive and measure it, often through science or objectivity. |
# | **Relativism**        | The perspective that knowledge and truth are relative to context; realities may be equally valid. |
# | **Infinite Regression**| A logical issue where each explanation relies on another explanation, potentially endlessly (e.g., turtles all the way down). |
# | **Skepticism**        | Philosophical position doubting the possibility of certain knowledge. |
# | **Foundationalism**   | Belief that knowledge rests on basic, unquestionable beliefs or experiences. |
# | **Coherentism**       | Epistemological theory that beliefs are justified by their coherence with other beliefs. |
# | **Procedural Justice**| The idea that the legitimacy of legal or institutional processes matters as much as outcomes. |
# | **Forensic Psychology**| The intersection of psychology and the criminal justice system. |
# | **Case Study**        | In-depth analysis of a single example, such as an event or individual, to illustrate complex issues. |
# ---
#
# ### Quiz
# 1. **What is positionality, and why is it crucial in research?**
# 2. **Explain the difference between epistemology and ontology.**
# 3. **Describe a real-world example where genetic and environmental factors both influenced an individual's behavior.**
# 4. **What is meant by "critical realism" in the context of research paradigms?**
# 5. **Why must researchers align their personal positionality with their research methods and topics?**
# 6. **What is infinite regression, and why is it a problem in argumentation?**
# 7. **How can one's beliefs about human nature (e.g., inherently good or bad) impact professional decisions in fields like forensic psychology?**
# 8. **Give an example of epigenetic influence as discussed in the lecture.**
# 9. **What distinguishes foundationalism from coherentism?**
# 10. **Why is critical self-reflection important for both research and personal relationships, according to the lecture?**
# ### Answers
# 1. **Positionality** refers to the researcher's unique standpoint and perspective; it's crucial because it shapes research questions, methods, interpretations, and biases.
# 2. **Epistemology** is about the nature and justification of knowledge; **ontology** concerns what exists or the nature of reality.
# 3. For example, a child exposed to trauma in the womb can have an increased risk for PTSD due to both parental experience (environment) and inherited gene expression (genetics).
# 4. **Critical realism** posits that while reality is independent and can be objectively measured, our understanding is filtered through subjective perception and context.
# 5. If researchers' personal views and methods misalign, their work could be biased, invalid, or lack integrity.
# 6. **Infinite regression** is an endless chain of justification without a solid starting point, making arguments or theories unverifiable.
# 7. If a psychologist believes people are inherently bad, they may judge criminal behavior more harshly or doubt rehabilitation; believing in inherent goodness might motivate forgiveness or reform efforts.
# 8. Example: Increased PTSD risk in grandchildren of 9/11 survivors, due to stress-induced changes in gene expression transmitted across generations.
# 9. **Foundationalism** holds that some base beliefs are self-justified; **coherentism** claims beliefs are justified by fitting together well with each other.
# 10. Critical self-reflection lets individuals recognize bias, improve research validity, and build healthier, more transparent relationships.

# %%
# improve katex formatting and add hallucination checks for each section
# in long term, let's build out knowledge bases for each subject to improve accuracy and reference in hallucination checks
