# %%
from pydantic import BaseModel, Field
from openai import OpenAI
from dotenv import load_dotenv
from typing import List

# %%
load_dotenv()
client = OpenAI()

# %%
class SentenceLine(BaseModel):
    """Schema for a transcript line"""
    line_number: int = Field(..., description="Line number in the transcript")
    text: str = Field(..., description="The sentence on this line")

class Section(BaseModel):
    """Schema for a transcript section"""
    header: str = Field(..., description="Header/title of the section")
    summary: str = Field(..., description = "Brief summary of the section")
    start_line: int = Field(..., description="Start line number of the section (inclusive)")
    end_line: int = Field(..., description="End line number of the section (inclusive)")

class AnnotatedTranscript(BaseModel):
    """Schema for a transcript"""
    summary: str = Field(..., description = "Detailed summary of the transcript")
    sections: List[Section] = Field(..., description="List of structured transcript sections")

# %%
def is_transcript_valid(split_transcript: dict, transcript_sections: list[dict]) -> tuple[bool, str]:
    """Check if annotated transcript is valid"""
    # length checking
    if transcript_sections[-1]["end_line"] > len(split_transcript):
        return False, "Annotated transcript contains more lines than original transcript"
    
    for i in range(len(transcript_sections)):
        transcript_section = transcript_sections[i]
        # type checking
        if (not isinstance(transcript_section["header"], str) or 
            not isinstance(transcript_section["summary"], str) or 
            not isinstance(transcript_section["start_line"], int) or 
            not isinstance(transcript_section["end_line"], int)):
            return False, "Section variables types are wrong"
        # value checking
        if (not transcript_section["header"] or 
            not transcript_section["summary"] or 
            not transcript_section["start_line"] >= 0 or 
            not transcript_section["end_line"] >= 0):
            return False, "Missing section information"
        
        if transcript_sections[i]["end_line"] < transcript_sections[i]["start_line"]:
            return False, "End line comes before start line"
        
        if i >= 1 and transcript_sections[i]["start_line"] != transcript_sections[i-1]["end_line"] + 1:
            return False, "Sections overlap, current section's start line comes before previous section's end line"
        
    return True, ""

# %%
def annotate_transcript(split_transcript: dict, messages: list[dict], iteration: int = 0) -> list[dict]:
    """Create an annotated transcript, broken up into sections by line numbers"""
    if iteration > 4:
        return
    
    res = client.beta.chat.completions.parse(
        model = "gpt-4.1",
        messages = messages,
        response_format = AnnotatedTranscript
    )

    annotated_transcript = res.choices[0].message.parsed.model_dump()
    messages.append({"role": "user", "content": str(annotated_transcript)})
    transcript_sections = annotated_transcript["sections"]

    is_valid = is_transcript_valid(split_transcript, transcript_sections)

    if not is_valid[0]:
        messages.append({"role": "user", "content": f"Re-annotate the transcript to address the following error: {is_valid[1]}"})
        annotate_transcript(split_transcript, messages, iteration + 1)
    return transcript_sections

# %%
def split_transcript_into_lines(transcript: str) -> dict:
    """
    Splits a raw transcript string into a list of lines.
    Returns a dictionary, with line number to line mappings
    """
    split_transcript = transcript.split('.')
    line_mappings = {index: line.strip() for index, line in enumerate(split_transcript)}
    return line_mappings

# %%
def normalize_section(section: dict, split_transcript: dict) -> dict:
    """Normalize a transcript section by combining lines into a single string"""
    transcript = ""
    start_line = section["start_line"]
    end_line = section["end_line"]

    for i in range(start_line, end_line):
        transcript += split_transcript[i] + "\n"

    return {
        "header": section["header"], 
        "summary": section["summary"], 
        "transcript": transcript
    }

# %%
class NoteSection(BaseModel):
    """Schema for a note section"""
    header: str = Field(..., description="Short, catchy header/title of the section formatted in markdown using '##'. Include a relevant emoji.")
    one_liner: str = Field(..., description = "Short, interesting, one-liner that encapsulates section. Put the one-liner in "". Use > 'quote' markdown")
    content: str = Field(..., description = "Detailed, bullet-points illustrating the section")

# %%
def generate_note_section(normalized_section: dict) -> dict:
    """Combine transcript section metadata and content to create a note section"""
    res = client.beta.chat.completions.parse(
        model = "gpt-4.1",
        messages = [
            {
                "role": "system", 
                "content": 
                    """
                    You are a course creator for a college class. 
                    Use the following section header, summary, and transcript to create a detailed note.
                    Indicate subheaders using '##', bold key terms and concepts for emphasis, use bullet points to represent lists, and indentation to indicate dependencies.
                    Format headers, one-liners, and text in markdown. Format math equations and symbols in katex.
                    """
            },
            {
                "role": "user", 
                "content": f"header: {normalized_section['header']} \n summary: {normalized_section['summary']} \n transcript: {normalized_section['transcript']}"
            }
        ],
        response_format = NoteSection
    )
    note_section = res.choices[0].message.parsed.model_dump()
    return note_section

# %%
def compile_note_section(note_section: dict) -> str:
    """Combine note section components into a string"""
    combined = note_section["header"] + "\n" + note_section["one_liner"] + "\n" + note_section["content"]
    return combined

# %%
class Extras(BaseModel):
    """Schema for additional content"""
    headline: str = Field(..., description = "Short, catchy title that encapsulates this lecture. Formatted in markdown using '##'.")
    summary: str = Field(..., description = "Short, engaging outline of the lecture. Begin with 'This lecture covers...'. Italicize in markdown using '*'.")
    todo_list: str = Field(
                            ..., 
                            description = 
                                    """
                                        Short list of the most important todos and next steps mentioned by the professor in the lecture. 
                                        Prioritize readings, exams, and assignments. 
                                        Include deadlines. 
                                        Format the title 'Todo List' in markdown using '###'.
                                        Use markdown format to **bold** parts of each todo. Keep each todo to 15 words or less. 
                                        Include markdown checkboxes '- [ ]' before each todo.
                                    """
                        )
    glossary: str = Field(..., description = "Glossary of key terms and definitions used throughout the lecture. Format the title 'Glossary' in markdown using '###'. Format the glossary as a markdown table with a divider '---' at the end.")
    quiz: str = Field(..., description = "Written quiz that tests a student's understanding of the lecture. Format the title 'quiz' in markdown using '###'.")
    answers: str = Field(..., description = "Answers to the written quiz. Format the title 'answers' in markdown using '###'.")

# %%
def generate_extras(transcript: str) -> dict:
    """Generate additional content"""
    res = client.beta.chat.completions.parse(
        model = "gpt-4.1",
        messages = [
            {
                "role": "system", 
                "content": 
                    """
                    You are a course creator for a college class. 
                    Generate a headline, summary, todo list, glossary, and quiz that reflects the following transcript.
                    Indicate subheaders using '##', bold key terms and concepts for emphasis, use bullet points to represent lists, and indentation to indicate dependencies.
                    Format the response in markdown. Format math equations and symbols in katex.
                    """
            },
            {
                "role": "user", 
                "content": transcript
            }
        ],
        response_format = Extras
    )
    extras = res.choices[0].message.parsed.model_dump()
    return extras

# %%
class Eval(BaseModel):
    """Schema for eval"""
    hallucinations: list[str] = Field(..., description = "Explanations of errors and inconsistencies")
    revisions: list[str] = Field(..., description = "Revisions made to correct the corresponding hallucination")
    score: int = Field(..., description = "Score (from 0% to 100%) that represents the percentage of the section that contained hallucinations")

# %%
def hallucination_check(note_section_text: str, transcript_section_text: str) -> dict:
    """Evaluate the accuracy of a note section against its corresponding transcript section"""
    res = client.beta.chat.completions.parse(
        model = "gpt-4.1",
        messages = [
            {
                "role": "system", 
                "content": 
                    """
                    You are a course creator for a college class. 
                    Evaluate the accuracy of an AI generated note section against the transcript section it represents.
                    """
            },
            {
                "role": "user", 
                "content": f"note section: {note_section_text} \n transcript section: {transcript_section_text}"
            }
        ],
        response_format = Eval
    )
    evaluation = res.choices[0].message.parsed.model_dump()
    return evaluation

# %%
def fix_hallucination(note_section_text: str, transcript_section_text: str, hallucinations: list[str], revisions: list[str]) -> dict:
    """Make revisions to resolve hallucinations"""
    res = client.beta.chat.completions.parse(
        model = "gpt-4.1",
        messages = [
            {
                "role": "system", 
                "content": 
                    """
                    You are a course creator for a college class. 
                    Given the following set of hallucinations and revisions that should be made, revise the AI generated note section such that it accurately represents the transcript section.
                    Maintain the style and formatting of the note section, and avoid making sweeping changes.
                    """
            },
            {
                "role": "user", 
                "content": 
                    f"""
                    note section: {note_section_text} 
                    transcript section: {transcript_section_text} 
                    hallucinations: {str(hallucinations)}
                    revisions: {str(revisions)}
                    """
            }
        ]
    )
    evaluation = res.choices[0].message.content
    return evaluation

# %%
def self_reflection(note_section_text: str, transcript_section_text: str, max_iterations: int, threshold: int):
    """Iteratively evaluate and revise note until a threshold or plateau is reached"""
    iteration = 0
    net_gain = 0
    scores = []
    note_sections = []
    max_index = 0

    while iteration < max_iterations:
        if scores and scores[-1] >= threshold:
            break
        if len(scores) >= 2:
            net_gain += scores[-1] - scores[-2]
        if net_gain <= -10:
            break

        eval = hallucination_check(note_section_text, transcript_section_text)
        scores.append(eval["score"])

        if scores[iteration] > scores[max_index]:
            max_index = iteration

        note_sections.append(note_section_text)
        note_section_text = fix_hallucination(note_section_text, 
                                              transcript_section_text, 
                                              eval["hallucinations"], 
                                              eval["revisions"]
                                              )
        iteration += 1

    return note_sections[max_index]

# %%
def compile_note(transcript: str) -> str:
    """
    Break a transcript into semantically meaningful sections
    Generate a note for each section, and additional content for the transcript
    Combine each note and additional content together
    """
    split_transcript = split_transcript_into_lines(transcript)
    messages = [
        {
            "role": "system", 
            "content": "Break the following transcript into 5 or 6 sections using the provided line numbers."
        },
        {
            "role": "user", 
            "content": str(split_transcript)
        }
    ]
    transcript_sections = annotate_transcript(split_transcript, messages)
    compiled_note_sections = []

    for transcript_section in transcript_sections:
        normalized_section = normalize_section(transcript_section, split_transcript)
        note_section = generate_note_section(normalized_section)
        compiled_note = self_reflection(compile_note_section(note_section), normalized_section["transcript"], max_iterations = 4, threshold = 0.98)
        compiled_note_sections.append(compiled_note)

    extras = generate_extras(transcript)

    combined_note_sections = ""
    for compiled_note_section in compiled_note_sections:
        combined_note_sections += compiled_note_section + "\n"

    combined_note = (
                        extras["headline"] + 
                        "\n" +
                        extras["summary"] + 
                        "\n" +
                        extras["todo_list"] + 
                        "\n" +
                        combined_note_sections +
                        extras["glossary"] +
                        "\n" +
                        extras["quiz"] +
                        "\n" +
                        extras["answers"]
                    )
    return combined_note

# %%
with open("C:/Users/Kaden/OneDrive/Professional/Athena/Note Creation/Semantic Chunking/transcripts/positionality.txt", encoding = "utf-8-sig") as f:
    transcript = f.read()

# %%
note = compile_note(transcript)

# %%
print(note)
# Out:
# ## The Power of Positionality: Nature, Nurture, and Knowledge in Research & Relationships
# *This lecture covers the critical importance of understanding positionality in research and professional practice, the interplay between genetic, environmental, and social influences on behavior and personality, as well as philosophical debates about reality, knowledge, and free will. Using case studies from forensic psychology, policing, and personal relationships, we consider how deeply-held beliefs, biases, and one's own place on the spectrum of objectivity/subjectivity dramatically impact analysis, judgment, and ethical choices.*
# ### Todo List
# - [ ] **Complete required reading on positionality and research paradigms before next seminar** (due next class)
# - [ ] **Read the Marine A case study and be ready to discuss in detail** (due by Friday)
# - [ ] **Review lecture notes on ontology, epistemology, and critical realism** (ongoing)
# - [ ] **Prepare reflection: Write your personal positionality statement** (due next week)
# - [ ] **Note time change: Monday lecture is rescheduled; check calendar for details**
# ## 🌎 Introduction to Positionality and Research Paradigms
# > Understanding positionality is the cornerstone of credible and self-aware research.
# - **Positionality Defined**
#   - Refers to your unique position in the world, encompassing:
#     - **Belief system**
#     - **Values**
#     - **Knowledge structures**: What knowledge you value and what you dismiss
#   - These elements shape how you interpret and conduct research
#
# - **Importance Across Disciplines**
#   - Positionality is **crucial for all subjects**; the ability to recognize and justify your positionality underpins the validity of your research
#   - Without acknowledging positionality, research is fundamentally flawed
#
# - **Philosophical Foundations**
#   - **Epistemology**: The philosophical theory of knowledge; examines:
#     - **Justified belief** vs. **opinion**
#     - Where your understanding falls on that spectrum
#   - **Ontology**: The study of the nature of reality; asks fundamental questions like “Does something exist?”
#
# - **Subjectivity in Knowledge and Analysis**
#   - Each individual brings a unique perspective to research, based on their own positionality
#     - This can lead to differing evaluations of what is considered valid or invalid knowledge
#
# - **Nature vs. Nurture Debate**
#   - Explored as an example of how positionality shapes thinking:
#     - Genetics (nature) vs. environment (nurture) in determining life outcomes
#     - Real-life anecdotes used to illustrate complex interplay (e.g., siblings raised apart sharing mannerisms)
#
# - **Scientific Example: PTSD Susceptibility**
#   - Questioned whether two newborns, with no environmental exposure yet, have equal risk for PTSD
#     - Class discussion highlighted the role of **genes** in predisposition to stress and trauma
#     - Environment may act as a trigger, but genetic factors contribute to resilience or vulnerability
#
# - **Key Takeaways**
#   - Researchers must continuously reflect on their own positionality
#   - Awareness of beliefs, experiences, and cultural background sharpens analysis and prevents blind spots
#   - Recognizing positionality leads to more credible, self-aware, and robust research
# ## 🧬 Nature vs. Nurture: Genetics and Epigenetics in Mental Health
# > The interplay between genes and environment shapes our psychological outcomes—even across generations!
# - **Nature vs. Nurture Debate**
#     - Explores whether genetics (nature) or environment/experiences (nurture) have a greater influence on behavior and psychological outcomes.
# - **Genetic Predispositions**
#     - Individuals may inherit certain genetic risks (e.g., for PTSD), but gene expression can vary.
#     - Genetic expression can be metaphorically 'turned on or off'—not all genes are active at all times.
# - **Epigenetics**
#     - Study of how environmental factors can change gene expression without altering DNA sequence.
#         - Examples: **Nutrition**, **maternal stress levels**, **time in utero**, and serious **traumatic events**.
#     - These changes can be measured and can have significant psychological effects.
# - **Generational Trauma**
#     - Research shows traumatic experiences (e.g., **9/11**) in one generation can impact subsequent generations.
#         - *Example*: Grandchildren of women who were pregnant during or close to 9/11 have a **~40% higher risk** of PTSD diagnosis.
#         - These effects are not directly inherited as 'memories,' but as altered gene expression (epigenetic markers).
#     - Trauma experienced by a parent or grandparent may influence a child's susceptibility to mental health conditions—even if the child wasn't exposed to the event or parent.
# - **Gene Expression Timing**
#     - Factors affecting gene expression:
#         - **Developmental timing**: Events in **pregnancy trimesters** are critical.
#         - **Chemical/hormonal changes** in the mother can change gene expression in the developing baby.
#     - Even when controlling for other variables (e.g., genetics, environment after birth), prenatal experiences can leave a measurable mark.
# - **Ongoing Research**
#     - Mechanisms are not fully understood, but the evidence links **stressful prenatal environments** with epigenetic changes that persist across generations.
#     - **Identifying specific genes** linked to PTSD risk helps understand and potentially reduce future vulnerability.
# ## 🧠 Knowledge, Reality, and Decision-Making in Forensic Psychology
# > The philosophical foundations of knowledge and reality shape beliefs, professional decisions, and justice in forensic psychology.
# - **Philosophical Frameworks and Perspectives:**
#    - Individuals differ on the fundamental nature of reality (e.g., belief in a deity, science-based explanations like the Big Bang, or other worldviews).
#    - How one conceptualizes reality influences every aspect of their interpretation and professional judgment—whether in daily interactions or scientific research.
#
# - **Influence on Forensic Psychology and Justice:**
#    - Beliefs about human nature (e.g., innate evil, capacity for change) strongly influence forensic psychologists’ actions, such as recommending rehabilitation or retribution for offenders.
#    - Attitudes towards clients (punitive vs. forgiving) are deeply rooted in these philosophical orientations.
#    - Judges, lawyers, and forensic experts may interpret the same facts differently based on foundational beliefs about truth, evidence, and moral responsibility.
#
# - **Metaphysics and Epistemology in Practice:**
#    - **Metaphysics:** Concerns the nature of reality—what exists versus what is imagined or constructed (e.g., the discussion of a purple mountain, or the anecdote about the infinite stack of turtles highlighting infinite regression).
#    - **Epistemology:** How knowledge is justified or validated; crucial frameworks include:
#       - **Empiricism:** Knowledge is derived from sensory experience and evidence (e.g., having seen rain or a leopard justifies imagining a leopard in the rain).
#       - **Foundationalism:** Knowledge builds upon basic, self-evident truths that serve as its foundation.
#       - **Coherentism:** Beliefs must cohere or fit together in a consistent system.
#       - **Skepticism:** Questioning whether true knowledge is possible at all, focusing on exposing doubt in others’ claims rather than proving one’s own.
#       - **Infinite Regress Problem:** The idea that every justification requires a further justification, leading to an endless chain (e.g., asking what supports the turtle under the earth).
#
# - **Professional Implications:**
#    - In forensic settings, skepticism and legal reasoning often operate by attempting to introduce reasonable doubt rather than proving an alternative truth.
#    - Psychologists and lawyers may challenge the validity (the "what") or reliability (the "how") of knowledge claims, influencing judgments about mental health, criminal intent, and capacity for change.
#    - Diagnostic and rehabilitation decisions can be affected by whether practitioners lean toward biological/genetic or social/environmental explanations of behavior.
#
# - **Takeaway:**
#    - Your stance on questions about knowledge and reality—whether empirical, skeptical, foundationalist, or otherwise—directly affects your approach to clients, research, and ethical dilemmas in forensic psychology.
# ## 🧠 Research Paradigms and the Objectivity–Subjectivity Spectrum
# > Your stance on reality shapes how you approach and interpret research.
# - **Positionality & Research**
#   - Understanding your **own stance (positionality)** is key for insightful research and critical analysis.
#   - Positionality influences:
#     - The types of questions you find valid.
#     - How you interpret evidence and design studies.
#     - Your interactions as a professional or scholar.
#
# - **Research Paradigms**
#   - A **paradigm** is a fundamental framework of beliefs and practices guiding research.
#   - Main paradigms identified:
#     - **Naive Realism:**
#       - Reality exists independently of our perceptions.
#       - True knowledge is what can be measured and objectively verified (e.g., lab experiments, biological/genetic evidence).
#     - **Subjectivism:**
#       - Reality is individually constructed.
#       - Each person’s experience is true for them; knowledge is inherently personal.
#     - **Relativism:**
#       - Reality is context-dependent and multiple viewpoints are valid.
#       - Boundaries may exist (bounded relativism) but knowledge is still not absolute.
#     - **Structuralism:**
#       - Science is valued, but societal structures (like institutions, funding) dictate what knowledge is pursued and "discovered".
#     - **Critical Realism:**
#       - Both objective (measurable) and subjective (personal/contextual) realities exist and matter.
#       - The most common modern stance among researchers.
#
# - **Alignment of Methodology and Positionality**
#   - Your research question and methods should align with your philosophical stance:
#     - E.g., If you believe only measurable, objective data counts, studying inherently subjective experiences (like perceptions of racism) may conflict with your paradigm.
#     - Incongruity leads to bias, weak analysis, and questionable professional practice.
#
# - **Case Studies: Genetics, Biology, and Behavior**
#   - Real-life scenario: A man developed paedophilic urges, later found to have a tumor; urges resolved after tumor removal, but returned with tumor recurrence.
#     - Illustrates how **biological factors**, like brain changes, can significantly affect behavior, challenging purely environmental or free will-based views.
#     - Sparks debate: Is behavior a result of biology, upbringing, experience, or a mix?
#   - Multiple participants shared personal/family examples illustrating:
#     - **Heritability of personality and attraction preferences**
#     - Influence of **brain chemistry** (hormones, life stage, disease) on desires/behavior
#     - Experience and learning can shift preferences, but biology often plays a strong role
#
# - **Implications for Research & Practice**
#   - Recognizing where you stand on the objectivity–subjectivity spectrum impacts how you:
#     - Formulate research questions
#     - Interpret case studies
#     - Make professional judgments in the field
#   - It's critical to be aware of **biases** and **philosophical assumptions** when evaluating or conducting research.
#   - **Critical reflection** (e.g., asking: "Does this argument align with my beliefs, and can I understand opposing stances?") is essential for robust analysis.
#
# - **Further Reading/Key Thinkers**
#   - Thomas Kuhn ("The Structure of Scientific Revolutions") for paradigms
#   - Robert Sapolsky (lectures on evolutionary biology and free will)
#
# Takeaway: Align your research paradigm, methodology, and personal stance for credible, meaningful inquiry.
# ## 🌱 Personal Reflections & Relationship Dynamics: Real Talk on Connection
# > Vulnerability and honesty set the stage for meaningful relationships, but personal growth and boundaries are non-negotiable.
# - **Authenticity and Self-Awareness**
#   - Participants candidly discussed their own histories, emotional health, and challenges in past and current relationships.
#   - Emphasis on **knowing oneself** before committing to another: "I need to find my safety first," "I'm just trying to be a good partner for me right now."
#   - Realization that sometimes, not being ready for partnership is an ethical and self-aware choice.
#
# - **Setting Boundaries**
#   - Open acknowledgment of one's limits, e.g., not wanting to "drag someone else into instability."
#   - Establishment of clear, mutual boundaries: honesty about financial, emotional, and logistical constraints.
#   - Reframing compromise as ongoing **negotiation**: not about losing, but explicit conversation.
#
# - **Impact of Instability, Trauma, and Change**
#   - Participants dealt with recent or ongoing instability (financial, residential, health), affecting their relationship capacity.
#   - References to trauma (e.g., past abuse, difficult breakups) and their impact on present-day intimacy and trust.
#   - Recognition that **healing and stability** are preconditions for being a "good partner."
#
# - **Honest Communication & Mutual Respect**
#   - Value placed on "giving enough information to make a conscious, consensual, informed choice" about moving forward.
#   - Highlighting the need to avoid being a placeholder or a savior for someone else.
#   - Respecting each other's journeys, even if that means pausing or reshaping the relationship.
#
# - **Realistic Expectations & Aspirations**
#   - Ideal outcomes include mutual growth and partnership, not codependence or transactional stability.
#   - Recognition that everyone is in a state of becoming, and genuine connection often requires both people to be on solid footing.
#   - The "Triple Win" principle: Is this relationship good for me, for you, and for the world/community?
#
# - **Personal Transformation & Emotional Labor**
#   - Stories of learning from failures, disappointments, and previous relationships were shared without shame, fostering empathy and connection.
#   - Acknowledgment that "knowing more" often means realizing how much is left to learn—both about others and oneself.
#   - Willingness to be "weird," incomplete, or in-progress, and to seek partners who appreciate that reality.
#
# - **The Desire for Authentic Partnership**
#   - Participants sought not just companionship, but someone with great communication, mutual respect, and aligned values—"a safe place," not a "leaning post."
#   - A shared wish for belonging, not out of necessity, but out of choice and compatibility.
#   - Practical barriers (long-distance, career, finances) were weighed honestly against emotional connection.
#
# - **Key Takeaways & Core Values**
#   - **Vulnerability** is essential, but must be matched by self-preservation and care.
#   - **Boundaries** protect both self and others; honesty fosters dignity and mutual respect.
#   - Transformative relationships require both partners to do their individual growth work first, striving for a foundation of stability and authentic connection.
# ### Glossary
# | Term                  | Definition |
# |-----------------------|------------|
# | **Positionality**     | The recognition and validation of one's own social and philosophical position, beliefs, and values in research and life. |
# | **Ontology**          | The philosophical study of the nature of reality and what exists. |
# | **Epistemology**      | The philosophical theory of knowledge, considering how knowledge is created, justified, and believed. |
# | **Empiricism**        | The practice or theory that knowledge is primarily derived from sensory experience and evidence. |
# | **Metaphysics**       | Branch of philosophy examining the fundamental nature of reality, existence, and the universe. |
# | **Infinite Regression** | Philosophical issue where every answer leads to another unanswerable question, e.g., 'turtles all the way down.' |
# | **Skepticism**        | Doubt as to the truth of something; in philosophy, the view that knowledge is uncertain. |
# | **Critical Realism**  | Philosophical stance combining belief in objective reality with acceptance of subjective interpretation. |
# | **Naive Realism**     | The belief that the world is exactly as we perceive it, entirely objective. |
# | **Relativism**        | The doctrine that knowledge, truth, and morality exist in relation to culture, society, or historical context, and are not absolute. |
# | **Epigenetics**       | Study of changes in gene expression not caused by changes in DNA sequence; how environment/experience affects genetic activity. |
# | **Foundationalism**   | Theory that basic beliefs exist and form the foundation for knowledge. |
# | **Coherentism**       | Theory that beliefs are justified by belonging to a coherent system of mutually supportive beliefs. |
# | **Forensic Psychology**| Field applying psychological principles to legal issues, typically in assessing and understanding criminal behavior. |
# | **Paradigm**          | A set of assumptions, concepts, values, and practices that constitutes a way of viewing reality for the community that shares them, especially in research. |
# | **Research Paradigm** | Framework of philosophies and methodologies underlying scientific inquiry. |
# ---
#
# ### Quiz
# 1. **Define positionality and explain why it is important in research.**
# 2. **Distinguish between ontology and epistemology.**
# 3. **What is the central debate in the nature vs. nurture discussion?**
# 4. **Describe what is meant by critical realism.**
# 5. **Give an example of how personal beliefs about human behavior (inherent good/evil) could influence forensic psychology practice.**
# 6. **Explain the concept of infinite regression using an example from the lecture.**
# 7. **How does epigenetics challenge the idea of a "blank slate" at birth?**
# 8. **Why is it problematic if a researcher does not know or cannot validate their own positionality?**
# 9. **What are foundationalism and coherentism in the context of knowledge?**
# 10. **Why is it important for research methods to be aligned with one's research paradigm and positionality?**
#
# ### Answers
# 1. **Positionality** is one's own unique position, beliefs, and values influencing research; it is important because unrecognized biases can distort research validity across all fields.
# 2. **Ontology** asks what exists (nature of reality); **Epistemology** asks how we know what we know (theory of knowledge).
# 3. The central debate is whether **genes/biology (nature)** or **environment/experience (nurture)** is more influential in shaping individuals.
# 4. **Critical realism** holds that while some aspects of reality are objective and can be measured, subjective interpretation is also significant.
# 5. Believing people are inherently evil may make a psychologist less likely to support rehabilitation or forgiveness; believing in growth may support their reintegration.
# 6. **Infinite regression** is when every answer generates new questions (e.g., "the world rests on a turtle"—what does the turtle rest on? Another turtle, ad infinitum).
# 7. **Epigenetics** shows life experiences (even of parents or grandparents) can alter gene expression, so babies aren't born as "blank slates."
# 8. A researcher unable to validate positionality may introduce hidden biases, undermining the credibility and integrity of their research.
# 9. **Foundationalism**: knowledge rests on basic, self-evident beliefs; **Coherentism**: knowledge is justified by coherence within a system of beliefs.
# 10. Methods and paradigms should align so beliefs about knowledge and reality are consistent with research practices, ensuring integrity and logical consistency.
